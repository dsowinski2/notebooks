# %%
import pandas as pd

# %%
df = pd.read_csv("charts-BrandAperture_Fusionary_inputs.csv", encoding = "ISO-8859-1", engine='python')

# %%
df
# Out:
#        Unnamed: 0 Unnamed: 1         Unnamed: 2    ADMIN Unnamed: 4  \
# 0             NaN      Brand           Industry  Country        NaN
# 1     placeholder        NaN                NaN      NaN        NaN
# 2             NaN        NaN                NaN      NaN        NaN
# 3             NaN          -                  -        -        NaN
# 4             NaN      Brand           Industry  Country       Year
# ...           ...        ...                ...      ...        ...
# 1038          NaN     Sodexo           Catering   France       2019
# 1039          NaN       Suez          Utilities   France       2019
# 1040          NaN        TF1              Media   France       2019
# 1041          NaN       Uber           Mobility   France       2019
# 1042          NaN      Vinci  Civil Engineering   France       2019
#
#                 GO-TO LENS Unnamed: 6     Unnamed: 7  \
# 0     Brand classification        NaN            NaN
# ...

# %%
chart_a1_data = df.iloc[:, 5:11]

# %%
brands = df.iloc[:, 1]

# %%
chart_a1 = pd.concat([brands, chart_a1_data], axis=1)

# %%
chart_a1 = chart_a1.drop(index = chart_a1.index[0:7])

# %%
chart_a1.columns = ['Brand', 'Users_connection', 'Users_progress', 'Users_quadrant', 'Prospect_quadrant', 'Prospect_progress', 'Prospect_quadrant']

# %%
chart_a1
# Out:
#                    Brand Users_connection Users_progress Users_quadrant  \
# 7      American Airlines              40%            45%       Enabling
# 8         Delta Airlines              49%            41%  Transactional
# 9      Hawaiian Airlines              59%            48%          Go-to
# 10      JetBlue Airlines              58%            49%          Go-to
# 11    Southwest Airlines              72%            64%          Go-to
# ...                  ...              ...            ...            ...
# 1038              Sodexo              17%            15%  Transactional
# 1039                Suez              22%            12%  Transactional
# 1040                 TF1              26%            11%  Transactional
# 1041                Uber              39%            41%          Go-to
# 1042               Vinci              10%            10%  Transactional
#
#              Prospect_quadrant         Prospect_progress  \
# ...

# %%
chart_a1.T.to_dict().values()
# Out:
# dict_values([{'Brand': 'American Airlines', 'Users_connection': '40%', 'Users_progress': '45%', 'Users_quadrant': 'Enabling', 'Prospect_quadrant': 'Enabling', 'Prospect_progress': '21%'}, {'Brand': 'Delta Airlines', 'Users_connection': '49%', 'Users_progress': '41%', 'Users_quadrant': 'Transactional', 'Prospect_quadrant': 'Go-to', 'Prospect_progress': '27%'}, {'Brand': 'Hawaiian Airlines', 'Users_connection': '59%', 'Users_progress': '48%', 'Users_quadrant': 'Go-to', 'Prospect_quadrant': 'Go-to', 'Prospect_progress': '33%'}, {'Brand': 'JetBlue Airlines', 'Users_connection': '58%', 'Users_progress': '49%', 'Users_quadrant': 'Go-to', 'Prospect_quadrant': 'Transactional', 'Prospect_progress': '17%'}, {'Brand': 'Southwest Airlines', 'Users_connection': '72%', 'Users_progress': '64%', 'Users_quadrant': 'Go-to', 'Prospect_quadrant': 'Go-to', 'Prospect_progress': '24%'}, {'Brand': 'United Airlines', 'Users_connection': '38%', 'Users_progress': '39%', 'Users_quadrant': 'Transactional', 'Pros
# ...

# %%
df = pd.DataFrame({'dfs':[chart_a1.T.to_dict().values(), chart_a1.T.to_dict().values()]}).T

# %%
df.columns = ['Chart_a1', 'Chart_a2']

# %%
df
# Out:
#                                               Chart_a1  \
# dfs  ({'Brand': 'American Airlines', 'Users_connect...
#
#                                               Chart_a2
# dfs  ({'Brand': 'American Airlines', 'Users_connect...
